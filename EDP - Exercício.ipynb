# %% [markdown]
# # Exercício
#
# Desenvolva os exercícios 15, 16, 17, 18 da página 462 do livro da Biblioteca Virtual – Equações Diferenciais 8ª Ed de autoria de Nagle, Saff e Snider.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# f(x) = \sin x - 6 \sin {4x}
# $$
#
# $$
# f(x) = \sin {3x} + 5 \sin {7x} - 2 \sin {13x}
# $$
#
# $$
# f(x) = \sin x - 7 \sin {3x} + \sin{5x}
# $$
#
# $$
# f(x) = \sin {4x} + 3 \sin {6x} - \sin {10x}
# $$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \frac{\partial u}{\partial t} = \beta \frac{\partial^2 u}{\partial x^2}
# $$
#
# $$
# u(x, t) = X(x) \cdot T(t)
# $$
#
# $$
# X(x) \cdot T'(t) = \beta X''(x) \cdot T(t)
# $$
#
# $$
# \frac{T'(t)}{T(t)} = \beta \frac{X''(x)}{X(x)}
# $$

# %% [markdown]
# $$
# \frac{T'(t)}{T(t)} = \beta \lambda
# $$
#
# $$
# \frac{X''(x)}{X(x)} = \lambda
# $$
#
# $$
# \begin{cases}
# \frac{T'(t)}{T(t)} = \beta \lambda \\
# \frac{X''(x)}{X(x)} = \lambda
# \end{cases}
# $$
#
# $$
# \begin{cases}
# T'(t) - \beta \lambda T(t) = 0 \\
# X''(x) - \lambda X(x) = 0
# \end{cases}
# $$

# %% [markdown]
# Para $ \lambda > 0 $:
#
# $$
# T(t) = C e^{\beta \lambda t}
# $$
#
# $$
# X(x) = A' e^{\sqrt{\lambda} x} + B' e^{-\sqrt{\lambda} x}
# $$
#
# $$
# u(x, t) = \left[
# A e^{\sqrt{\lambda} x} + B e^{-\sqrt{\lambda} x}
# \right]
# \cdot
# e^{\beta \lambda t}
# $$

# %% [markdown]
# Para $ \lambda = 0 $:
#
# $$
# T(t) = C
# $$
#
# $$
# X(x) = A' + B'x
# $$
#
# $$
# u(x, t) = A + Bx
# $$

# %% [markdown]
# Para $ \lambda < 0 $:
#
# $$
# X(t) = A' \cos \left(\sqrt{-\lambda} x\right) + B' \sin \left(\sqrt{-\lambda} x\right)
# $$
#
# $$
# u(x, t) = \left[
# A \cos \left(\sqrt{-\lambda} x\right) + B \sin \left(\sqrt{-\lambda} x\right)
# \right]
# \cdot
# e^{\beta \lambda t}
# $$

# %% [markdown]
# Caso 1 e caso 2, leva para a solução trivial.
#
# Para o caso 3, vamos impor as condições de contorno:
#
# $$
# u(0,  t) = A e^{\beta \lambda t} = 0 \quad \rightarrow \quad A = 0
# $$
#
# $$
# u(L, t) = \left[B \sin \left(\sqrt{-\lambda} L\right)
# \right]
# \cdot
# e^{\beta \lambda t} = 0
# \quad \rightarrow \sqrt{-\lambda} = \frac{n\pi}{L} \quad, n\in\mathbb{N}
# $$

# %% [markdown]
# $$
# u(x, t) = \sum_{n=0}^{\infty} \left( b_n \sin \left( \frac{n\pi}{L} x\right) \cdot e^{-\frac{n^2\beta\pi^2}{L^2} t} \right)
# $$

# %% [markdown]
# Vamos agora impor as condições de distribuição inicial de temperatura.
#
# **(Exemplo 15)**
# $$
# f(x) = \sin x - 6 \sin {4x}
# $$
#
# $$
# u(x, 0) = \sum_{n=0}^{\infty} b_n \sin \left( \frac{n\pi}{L} x\right) =
# \sin x -6 \sin {4x}
# $$

# %% [markdown]
# $$
# \begin{cases}
# b_1 = 1 \\
# b_4 = -6 \\
# b_n = 0, n \neq 1 \wedge n \neq 4
# \end{cases}
# $$

# %% [markdown]
# $$
# u(x, t) = e^{-t} \sin x - 6 e^{-16t} \sin {4x}
# $$

# %%
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

u = lambda x, t: np.exp(-t)*np.sin(x) - 6*np.exp(-16*t)*np.sin(4*x)

def draw_u(t):
    global left, right, top, bottom
    plt.figure(2, figsize=(15,12))
    x = np.linspace(0, np.pi)
    plt.plot(x, u(x, 0), label='temperatura inicial')
    plt.plot(x, u(x, t), label='temperatura atual')
    plt.grid(which='both')
    plt.title('Temperatura')
    plt.xlabel('Cota (mm)')
    plt.ylabel('Temperatura (°C)')
    plt.legend()
    plt.show()

interactive_plot = interactive(draw_u, t=(0., .8, .01))
output = interactive_plot.children[-1]
output.layout.height = '700px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.4, description='t', max=0.8, step=0.01), Output(layout=Layout(height…

# %%
x = np.linspace(0, np.pi)

fig = plt.figure(figsize=(15, 12))
for t in np.linspace(0, 0.5, 10):
    plt.plot(x, u(x, t), color='black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, np.pi)
t = np.linspace(0, 0.5)
x, t = np.meshgrid(x, t)
fig = plt.figure(figsize=(15, 12))
ax=plt.axes(projection='3d')
ax.plot_surface(x, t, u(x, t))
plt.show()

# %% [markdown]
# **(Exemplo 16)**
# $$
# f(x) = \sin {3x} + 5 \sin {7x} - 2 \sin {13x}
# $$
#
# $$
# u(x, 0) = \sum_{n=0}^{\infty} b_n \sin \left( \frac{n\pi}{L} x\right) =
# \sin {3x} + 5 \sin {7x} - 2 \sin {13x}
# $$
#
# $$
# u(x, t) = e^{-9t}\sin {3x} + 5 e^{-49t} \sin {7x} - 2 e^{-169t} \sin {13x}
# $$

# %%
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

u = lambda x, t: np.exp(-9*t)*np.sin(3*x) + 5*np.exp(-49*t)*np.sin(7*x) - 2 * np.exp(-169*t)*np.sin(13*t)

def draw_u(t):
    global left, right, top, bottom
    plt.figure(2, figsize=(15,12))
    x = np.linspace(0, np.pi, 150)
    plt.plot(x, u(x, 0), label='temperatura inicial')
    plt.plot(x, u(x, t), label='temperatura atual')
    plt.grid(which='both')
    plt.title('Temperatura')
    plt.xlabel('Cota (mm)')
    plt.ylabel('Temperatura (°C)')
    plt.legend()
    plt.show()

interactive_plot = interactive(draw_u, t=(0., .5, .01))
output = interactive_plot.children[-1]
output.layout.height = '700px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.25, description='t', max=0.5, step=0.01), Output(layout=Layout(heigh…

# %%
x = np.linspace(0, np.pi, 120)

fig = plt.figure(figsize=(15, 12))
for t in np.linspace(0, 0.1, 10):
    plt.plot(x, u(x, t), color='black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, np.pi)
t = np.linspace(0, 0.5)
x, t = np.meshgrid(x, t)
fig = plt.figure(figsize=(15, 12))
ax=plt.axes(projection='3d')
ax.plot_surface(x, t, u(x, t))
plt.show()

# %% [markdown]
# **(Exemplo 17)**
# $$
# f(x) = \sin x - 7 \sin {3x} + \sin{5x}
# $$
#
# $$
# u(x, 0) = \sum_{n=0}^{\infty} b_n \sin \left( \frac{n\pi}{L} x\right) =
# \sin x - 7 \sin {3x} + \sin{5x}
# $$

# %% [markdown]
# $$
# u(x, t) = e^{-t} \sin x - 7 e^{-9t} \sin {3x} + e^{-25t} \sin {5t}
# $$

# %%
u = lambda x, t: np.exp(-t)*np.sin(x) - 7*np.exp(-9*t)*np.sin(3*x) + exp(-25*t)*np.sin(5*t)

# %%
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

u = lambda x, t: np.exp(-9*t)*np.sin(3*x) + 5*np.exp(-49*t)*np.sin(7*x) - 2 * np.exp(-169*t)*np.sin(13*t)

def draw_u(t):
    global left, right, top, bottom
    plt.figure(2, figsize=(15,12))
    x = np.linspace(0, np.pi, 150)
    plt.plot(x, u(x, 0), label='temperatura inicial')
    plt.plot(x, u(x, t), label='temperatura atual')
    plt.grid(which='both')
    plt.title('Temperatura')
    plt.xlabel('Cota (mm)')
    plt.ylabel('Temperatura (°C)')
    plt.legend()
    plt.show()

interactive_plot = interactive(draw_u, t=(0., .5, .01))
output = interactive_plot.children[-1]
output.layout.height = '700px'
interactive_plot
# Out:
# interactive(children=(FloatSlider(value=0.25, description='t', max=0.5, step=0.01), Output(layout=Layout(heigh…

# %%
x = np.linspace(0, np.pi, 120)

fig = plt.figure(figsize=(15, 12))
for t in np.linspace(0, 0.1, 10):
    plt.plot(x, u(x, t), color='black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, np.pi)
t = np.linspace(0, 0.5)
x, t = np.meshgrid(x, t)
fig = plt.figure(figsize=(15, 12))
ax=plt.axes(projection='3d')
ax.plot_surface(x, t, u(x, t))
plt.show()
